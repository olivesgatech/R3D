# %%
# !python3 main_darai.py
# Out:
# using gpu
# runs :  0
# model type :  futr
# input type :  i3d_transcript
# Epoch :  60
# batch size :  8
# Split :  1
# Traceback (most recent call last):
#   File "main_darai.py", line 181, in <module>
#     main(seed[0], dataset_ops)
#   File "main_darai.py", line 112, in main
#     model = FUTR(n_class, args.hidden_dim, device=device, args=args, src_pad_idx=pad_idx,
#   File "/storage/ice1/7/2/skim3513/darai-anticipation/FUTR_proposed/model/futr_unsupervised_depth.py", line 56, in __init__
#     self.positional_embedding_l3 = self.positional_embedding_l3.to(self.device)
#   File "/home/hice1/skim3513/AIFirst_F24_data/anaconda3/envs/torch190/lib/python3.8/site-packages/torch/cuda/__init__.py", line 172, in _lazy_init
#     torch._C._cuda_init()
# RuntimeError: CUDA driver initialization failed, you might not have a CUDA gpu.

# %%
import torch

torch.cuda.is_available()
# Out:
# False

# %%
# !module load cuda/12.3
# Out:
# Lmod has detected the following error:  The following module(s) are
# unknown: "cuda/12.3"
#
# Please check the spelling or version number. Also try "module spider ..."
# It is also possible your cache file is out-of-date; it may help to try:
#   $ module --ignore_cache load "cuda/12.3"
#
# Also make sure that all modulefiles written in TCL start with the string
# #%Module

# %%
# !sbatch run.sh
# Out:
# Submitted batch job 2400945

# %%
# !scancel 1727448

# %%
# !python3 main_utkinects.py
# Out:
# /home/hice1/skim3513/AIFirst_F24_data/anaconda3/envs/myenv3/lib/python3.8/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /home/hice1/skim3513/AIFirst_F24_data/anaconda3/envs/myenv3/lib/python3.8/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /home/hice1/skim3513/AIFirst_F24_data/anaconda3/envs/myenv3/lib/python3.8/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
# ...

# %%
# !nvidia-smi
# Out:
# Wed Mar  5 13:46:28 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 555.42.02              Driver Version: 555.42.02      CUDA Version: 12.5     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 80GB HBM3          On  |   00000000:0A:00.0 Off |                    0 |
# | N/A   42C    P0            141W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...
